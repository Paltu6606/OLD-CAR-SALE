# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('CAR DETAILS.csv')
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 763

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
df.shape
# Out:
# (3577, 8)

# %%
cols=df.columns
cols
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
cat_cols=df.dtypes[df.dtypes=='object'].index
num_cols=df.dtypes[df.dtypes!='object'].index
print(cat_cols)
print(num_cols)
# Out:
# Index(['name', 'fuel', 'seller_type', 'transmission', 'owner'], dtype='object')
# Index(['year', 'selling_price', 'km_driven'], dtype='object')

# %%
a =  df[num_cols].describe(percentiles=[0.01,0.02,0.03,0.25,0.5,0.75,0.80,0.85,0.90,0.95,0.97,0.98,0.99]).T
a
# Out:
#                 count           mean            std      min        1%  \
# year           3577.0    2012.962538       4.251759   1992.0   2000.00
# selling_price  3577.0  473912.542074  509301.809816  20000.0  51786.64
# km_driven      3577.0   69250.545709   47579.940016      1.0   1744.08
#
#                     2%       3%       25%       50%       75%       80%  \
# year            2003.0   2004.0    2010.0    2013.0    2016.0    2017.0
# selling_price  60000.0  70000.0  200000.0  350000.0  600000.0  650000.0
# km_driven       5000.0   6525.2   36000.0   60000.0   90000.0  100000.0
#
#                     85%       90%        95%        97%        98%        99%  \
# year             2017.0    2018.0     2019.0     2019.0     2019.0     2020.0
# selling_price  750000.0  875000.0  1200000.0  1497200.0  1800000.0  2675000.0
# km_driven      110000.0  120000.0   149534.8   170000.0   193440.0   223158.4
#
#                      max
# year              2020.0
# selling_price  8900000.0
# km_driven       806599.0

# %%
df = df[(df['selling_price'] > 0) & (df['km_driven'] > 0)]
print(df.describe())
# Out:
#               year  selling_price      km_driven
# count  3577.000000   3.577000e+03    3577.000000
# mean   2012.962538   4.739125e+05   69250.545709
# std       4.251759   5.093018e+05   47579.940016
# min    1992.000000   2.000000e+04       1.000000
# 25%    2010.000000   2.000000e+05   36000.000000
# 50%    2013.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
print('Year : ',df.year.unique(),'\n')
print('fuel :', df.fuel.unique(), '\n')
print('Transmission : ', df.transmission.unique(), '\n')
print('seller Type: :', df.seller_type.unique(),'\n')
print('Owner :', df.owner.unique(), '\n')
# Out:
# Year :  [2007 2012 2017 2014 2016 2015 2018 2019 2013 2011 2010 2009 2006 1996
#  2005 2008 2004 1998 2003 2002 2020 2000 1999 2001 1995 1997 1992]
#
# fuel : ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
#
# Transmission :  ['Manual' 'Automatic']
#
# seller Type: : ['Individual' 'Dealer' 'Trustmark Dealer']
#
# Owner : ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
df['brand']=df['name'].str.split(expand=True)[0]
df['model']=df['name'].str.split(expand=True)[1]
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    brand   model
# 0  Individual       Manual   First Owner   Maruti     800
# 1  Individual       Manual   First Owner   Maruti   Wagon
# 2  Individual       Manual   First Owner  Hyundai   Verna
# 3  Individual       Manual   First Owner   Datsun  RediGO
# 4  Individual       Manual  Second Owner    Honda   Amaze

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df['fuel_type'] = lb.fit_transform(df['fuel'])
df['Type_of_Seller'] = lb.fit_transform(df['seller_type'])
df['Transmit'] = lb.fit_transform(df['transmission'])
df['Owner_Type'] = lb.fit_transform(df['owner'])
df['brand_name'] = lb.fit_transform(df['brand'])
df['model_name'] = lb.fit_transform(df['model'])

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    brand   model  fuel_type  \
# 0  Individual       Manual   First Owner   Maruti     800          4
# 1  Individual       Manual   First Owner   Maruti   Wagon          4
# 2  Individual       Manual   First Owner  Hyundai   Verna          1
# 3  Individual       Manual   First Owner   Datsun  RediGO          4
# 4  Individual       Manual  Second Owner    Honda   Amaze          1
#
#    Type_of_Seller  Transmit  Owner_Type  brand_name  model_name
# 0               1         1           0          18           6
# 1               1         1           0          18         164
# 2               1         1           0          10         161
# 3               1         1           0           5         125
# 4               1         1           2           9          17

# %%
data = df.drop(['name', 'fuel', 'seller_type', 'transmission', 'owner', 'brand','model'], axis=1)
data.head()
# Out:
#    year  selling_price  km_driven  fuel_type  Type_of_Seller  Transmit  \
# 0  2007          60000      70000          4               1         1
# 1  2007         135000      50000          4               1         1
# 2  2012         600000     100000          1               1         1
# 3  2017         250000      46000          4               1         1
# 4  2014         450000     141000          1               1         1
#
#    Owner_Type  brand_name  model_name
# 0           0          18           6
# 1           0          18         164
# 2           0          10         161
# 3           0           5         125
# 4           2           9          17

# %%
data.dtypes
# Out:
# year              int64
# selling_price     int64
# km_driven         int64
# fuel_type         int64
# Type_of_Seller    int64
# Transmit          int64
# Owner_Type        int64
# brand_name        int64
# model_name        int64
# dtype: object

# %%
def treatment_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
for i in num_cols:
    data = treatment_outliers(data, i)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.drop(columns=['selling_price'])
y = data['selling_price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2600, 8)
# (2600,)
# (650, 8)
# (650,)

# %%
from sklearn.metrics import *

# %%
def eval_model(model,mname):
    model.fit(x_train,y_train)
    ypred = model.predict(x_test)
    train_r2 = model.score(x_train,y_train)
    test_r2 = model.score(x_test,y_test)
    mae = mean_absolute_error(y_test,ypred)
    mse = mean_squared_error(y_test,ypred)
    rmse = np.sqrt(mse)
    res = pd.DataFrame({'Train_R2':train_r2,'Test_R2':test_r2,'MAE':mae,
                       'MSE':mse,'RMSE':rmse},index=[mname])
    return res,ypred

# %%
from sklearn.linear_model import *
from sklearn.tree import *
from sklearn.ensemble import *
from sklearn.neighbors import *
from xgboost import XGBRegressor

# %%
lr = LinearRegression()
lr_res,ypred_lr = eval_model(lr,'LinReg')
lr_res
# Out:
#         Train_R2   Test_R2            MAE           MSE           RMSE
# LinReg  0.516628  0.530195  132100.592449  3.114462e+10  176478.388762

# %%
dt = DecisionTreeRegressor(max_depth=6,min_samples_split=8)
dt_res,ypred_dt = eval_model(dt,'DT_Reg')
dt_res
# Out:
#         Train_R2   Test_R2           MAE           MSE           RMSE
# DT_Reg  0.688303  0.625997  112056.21618  2.479368e+10  157460.076648

# %%
knn = KNeighborsRegressor(n_neighbors=11)
knn_res,ypred_knn = eval_model(knn,'KNN_Reg')
knn_res
# Out:
#          Train_R2  Test_R2            MAE           MSE           RMSE
# KNN_Reg  0.310396  0.23331  174572.090769  5.082592e+10  225446.053086

# %%
rf = RandomForestRegressor(n_estimators=80,max_depth=6,min_samples_split=8)
rf_res,ypred_rf = eval_model(rf,'RF_Reg')
rf_res
# Out:
#         Train_R2   Test_R2            MAE           MSE           RMSE
# RF_Reg  0.724005  0.689567  104508.355661  2.057946e+10  143455.418478

# %%
rg = Ridge()
rg_res,y_pred_rg = eval_model(rg,'Ridge_reg')
rg_res
# Out:
#            Train_R2   Test_R2            MAE           MSE           RMSE
# Ridge_reg  0.516626  0.530158  132107.951228  3.114709e+10  176485.380828

# %%
ls = Lasso()
ls_res,y_pred_rg = eval_model(ls,'Lasso_reg')
ls_res
# Out:
#            Train_R2   Test_R2            MAE           MSE           RMSE
# Lasso_reg  0.516628  0.530194  132100.673656  3.114466e+10  176478.491726

# %%
all_res  = pd.concat([lr_res,dt_res,knn_res,rf_res,rg_res,ls_res])
all_res
# Out:
#            Train_R2   Test_R2            MAE           MSE           RMSE
# LinReg     0.516628  0.530195  132100.592449  3.114462e+10  176478.388762
# DT_Reg     0.688303  0.625997  112056.216180  2.479368e+10  157460.076648
# KNN_Reg    0.310396  0.233310  174572.090769  5.082592e+10  225446.053086
# RF_Reg     0.724005  0.689567  104508.355661  2.057946e+10  143455.418478
# Ridge_reg  0.516626  0.530158  132107.951228  3.114709e+10  176485.380828
# Lasso_reg  0.516628  0.530194  132100.673656  3.114466e+10  176478.491726

# %%
import pickle
import joblib

# %%
pickle.dump(rf,open('Best_Model_1.pkl','wb'))

# %%
load_model=joblib.load('Best_Model_1.pkl')

# %%
random_indices = np.random.choice(data.index, size= 20, replace=False)
sample_data_20 = data.loc[random_indices]
sample_data_20
# Out:
#       year  selling_price  km_driven  fuel_type  Type_of_Seller  Transmit  \
# 3505  2012         280000      80000          1               1         1
# 985   2015         950000      60000          1               1         1
# 478   2011         300000      65000          1               1         1
# 1711  2001          45000      72539          4               1         1
# 3439  2017         785000      24000          1               1         1
# 880   2011         285000      50000          1               1         1
# 3757  2011         300000      64000          4               1         1
# 1512  2018         790000      40000          1               1         1
# 3881  2017         434999      16267          4               0         1
# 1721  2015         320000      60000          1               1         1
# 3628  2018         310000      15000          4               1         1
# 2310  2014         300000     120000          1               1         1
# 4039  2019         335000      28000          4               0         1
# 1066  2018         780000      25000          1               0         1
# 874   2017         160000      50000          4               1         1
# 844   2013         450000     120000          1               1         1
# 3600  2012         750000     100000          1               1         0
# 3826  2009          70000      60000          4               1         1
# 367   2012         550000      80000          1               1         1
# 3924  2014         500000     140000          1               1         1
#
#       Owner_Type  brand_name  model_name
# 3505           2           8          65
# 985            0          10          44
# 478            2          27         157
# 1711           2          18           6
# 3439           0          18          58
# 880            2          18         147
# 3757           2           9          39
# 1512           2           8          51
# 3881           0          21         100
# 1721           0          18         147
# 3628           0          23          90
# 2310           0          18         147
# 4039           0          18          14
# 1066           0           9          17
# 874            0          18          14
# 844            0          23          48
# 3600           2           2         167
# 3826           4           3         142
# 367            0          17         174
# 3924           2          26          61

# %%
sample_data=sample_data_20.drop('selling_price', axis=1)

# %%
Sample_pred = load_model.predict(sample_data)
Sample_pred
# Out:
# array([284489.91748354, 562585.43421336, 319881.90343984,  98730.81732792,
#        752983.11409812, 305890.58887439, 251741.18349859, 779007.63844433,
#        489988.1608212 , 521064.15557155, 494910.18317018, 474548.61380238,
#        322585.82449589, 783886.37097776, 230103.91785426, 381794.03943158,
#        684044.49939611, 175893.15336739, 428345.65486019, 602276.19502242])

# %%
Prediction_sample = pd.DataFrame(Sample_pred)
Prediction_sample
# Out:
#                 0
# 0   284489.917484
# 1   562585.434213
# 2   319881.903440
# 3    98730.817328
# 4   752983.114098
# 5   305890.588874
# 6   251741.183499
# 7   779007.638444
# 8   489988.160821
# 9   521064.155572
# 10  494910.183170
# 11  474548.613802
# 12  322585.824496
# 13  783886.370978
# 14  230103.917854
# 15  381794.039432
# 16  684044.499396
# 17  175893.153367
# 18  428345.654860
# 19  602276.195022

# %%
print(sample_data_20[['selling_price', 'year']])
# Out:
#       selling_price  year
# 3505         280000  2012
# 985          950000  2015
# 478          300000  2011
# 1711          45000  2001
# 3439         785000  2017
# 880          285000  2011
# 3757         300000  2011
# 1512         790000  2018
# 3881         434999  2017
# 1721         320000  2015
# 3628         310000  2018
# 2310         300000  2014
# 4039         335000  2019
# 1066         780000  2018
# 874          160000  2017
# 844          450000  2013
# 3600         750000  2012
# 3826          70000  2009
# 367          550000  2012
# 3924         500000  2014

# %%
sample_data_20['pred_selling_price']=Prediction_sample.values
sample_data_20
# Out:
#       year  selling_price  km_driven  fuel_type  Type_of_Seller  Transmit  \
# 3505  2012         280000      80000          1               1         1
# 985   2015         950000      60000          1               1         1
# 478   2011         300000      65000          1               1         1
# 1711  2001          45000      72539          4               1         1
# 3439  2017         785000      24000          1               1         1
# 880   2011         285000      50000          1               1         1
# 3757  2011         300000      64000          4               1         1
# 1512  2018         790000      40000          1               1         1
# 3881  2017         434999      16267          4               0         1
# 1721  2015         320000      60000          1               1         1
# 3628  2018         310000      15000          4               1         1
# 2310  2014         300000     120000          1               1         1
# 4039  2019         335000      28000          4               0         1
# 1066  2018         780000      25000          1               0         1
# 874   2017         160000      50000          4               1         1
# 844   2013         450000     120000          1               1         1
# 3600  2012         750000     100000          1               1         0
# 3826  2009          70000      60000          4               1         1
# 367   2012         550000      80000          1               1         1
# 3924  2014         500000     140000          1               1         1
#
#       Owner_Type  brand_name  model_name  pred_selling_price
# 3505           2           8          65       284489.917484
# 985            0          10          44       562585.434213
# 478            2          27         157       319881.903440
# 1711           2          18           6        98730.817328
# 3439           0          18          58       752983.114098
# 880            2          18         147       305890.588874
# 3757           2           9          39       251741.183499
# 1512           2           8          51       779007.638444
# 3881           0          21         100       489988.160821
# 1721           0          18         147       521064.155572
# 3628           0          23          90       494910.183170
# 2310           0          18         147       474548.613802
# 4039           0          18          14       322585.824496
# 1066           0           9          17       783886.370978
# 874            0          18          14       230103.917854
# 844            0          23          48       381794.039432
# 3600           2           2         167       684044.499396
# 3826           4           3         142       175893.153367
# 367            0          17         174       428345.654860
# 3924           2          26          61       602276.195022

# %%
com = (sample_data_20[['selling_price', 'pred_selling_price']])
com.to_csv('sample_prediction.csv')
com
# Out:
#       selling_price  pred_selling_price
# 3505         280000       284489.917484
# 985          950000       562585.434213
# 478          300000       319881.903440
# 1711          45000        98730.817328
# 3439         785000       752983.114098
# 880          285000       305890.588874
# 3757         300000       251741.183499
# 1512         790000       779007.638444
# 3881         434999       489988.160821
# 1721         320000       521064.155572
# 3628         310000       494910.183170
# 2310         300000       474548.613802
# 4039         335000       322585.824496
# 1066         780000       783886.370978
# 874          160000       230103.917854
# 844          450000       381794.039432
# 3600         750000       684044.499396
# 3826          70000       175893.153367
# 367          550000       428345.654860
# 3924         500000       602276.195022
